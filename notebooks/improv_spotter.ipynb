# %%
import pandas as pd

# %%
import nltk

# Download the missing WordNet resource
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/josecerqueira/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
web_scrape_comments = pd.read_csv("web_scrape_comments.csv")

# %%
web_scrape_comments
# Out:
#           id           name  anonymous hostProgramName  graduatingYear  \
# 0     306372  Sergio Burgos      False             NaN          2023.0
# 1     306215      Anonymous       True             NaN          2023.0
# 2     306068      Anonymous       True             NaN          2023.0
# 3     305297    Utku Cikmaz      False             NaN          2023.0
# 4     305278   Nirmal Hodge      False             NaN          2023.0
# ...      ...            ...        ...             ...             ...
# 4037  234894   Stephanie S.      False             NaN          2015.0
# 4038  234877       Joe Fang      False             NaN          2015.0
# 4039  234838          Zeina      False             NaN          2016.0
# 4040  242681           Jean      False             NaN          2016.0
# 4041  234178            Ben      False             NaN          2016.0
#
#       isAlumni                         jobTitle  \
# 0        False         International Negotiator
# ...

# %%
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet

# Download NLTK resources
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/josecerqueira/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/josecerqueira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/josecerqueira/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Function to get synonyms:

# %%
def get_synonyms(word):
    synonyms = []
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())
    return synonyms

# %%
def filter_improvement_comments(comment):
    words = word_tokenize(comment.lower())
    
    words = [word for word in words if word.isalnum() and word not in stopwords.words("english")]

    target_word = "improvement"
    synonyms = get_synonyms(target_word)
    
    return any(word in words for word in [target_word] + synonyms)

# %%
filtered_web_scrape_comments = web_scrape_comments[web_scrape_comments["review_body"].apply(filter_improvement_comments)]

# Display the filtered DataFrame
filtered_web_scrape_comments
# Out:
#           id              name  anonymous hostProgramName  graduatingYear  \
# 76    295724             Paola      False             NaN          2020.0
# 139   293171       João Cabral      False             NaN          2022.0
# 166   289606         Anonymous       True             NaN          2022.0
# 183   286102       Dafne Lopez      False             NaN          2022.0
# 243   275872      Ahmad Khalaf      False             NaN          2021.0
# ...      ...               ...        ...             ...             ...
# 3864  245878    Jonas Cuadrado      False    Data Science          2018.0
# 3976  243423      Katie Fitton      False    UX/UI Design          2018.0
# 4020  235481  Landon Barnickle      False             NaN          2017.0
# 4021  235228         Anonymous      False             NaN          2016.0
# 4030  232997        Shivani S.      False             NaN          2016.0
#
#       isAlumni                      jobTitle  \
# ...

# %%
filtered_web_scrape_comments_2 = filtered_web_scrape_comments["review_body"]

# %%
file_path = 'web_scrape_comments_improved.csv'

# Save the DataFrame to a CSV file
filtered_web_scrape_comments_2.to_csv(file_path, index=False)

# %%
pd.DataFrame(filtered_web_scrape_comments_2)
# Out:
#                                             review_body
# 76    I was in the data analytics part time bootcamp...
# 139   I really have to take some time to speak about...
# 166   It was an amazing experience to learn from gre...
# 183   Recently I became a proud Ironhack Alumni! I d...
# 243   When I started I was a little disappointed but...
# ...                                                 ...
# 3864  I recently completed the Data Science career t...
# 3976  Springboard has a practical, relevant, and pro...
# 4020  Springboard's Data Science Intensive is a grea...
# 4021  This course was a great and fair step in helpi...
# 4030  My prime goal with this course was to advance ...
#
# [82 rows x 1 columns]

# %%
filtered_web_scrape_comments_2
# Out:
# 76      I was in the data analytics part time bootcamp...
# 139     I really have to take some time to speak about...
# 166     It was an amazing experience to learn from gre...
# 183     Recently I became a proud Ironhack Alumni! I d...
# 243     When I started I was a little disappointed but...
#                               ...
# 3864    I recently completed the Data Science career t...
# 3976    Springboard has a practical, relevant, and pro...
# 4020    Springboard's Data Science Intensive is a grea...
# 4021    This course was a great and fair step in helpi...
# 4030    My prime goal with this course was to advance ...
# Name: review_body, Length: 82, dtype: object
